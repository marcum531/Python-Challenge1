# %%
#import dependencies
import pandas as pd
import csv
import os
import datetime as date
import re
import requests

# %%
PyBoss_df = pd.read_csv(r"C:\Users\marcu\OneDrive\Desktop\Python_Challenge1\Python-Challenge1\PyBoss\Employee_Data.csv")
PyBoss_df
# Out:
#      Emp ID              Name         DOB          SSN         State
# 0       232      John Mathews   2/24/1991  289-31-9165  North Dakota
# 1       533      Nathan Moore  11/19/1978  220-05-7469         Maine
# 2       256    Amanda Douglas    1/8/1990  564-27-6961         Idaho
# 3       189   Heather Andrews   8/11/1976  742-79-1797       Vermont
# 4       284  Daniel Hernandez   7/22/1976  656-01-7473      Colorado
# ..      ...               ...         ...          ...           ...
# 645     235  Cameron Mcintosh    2/1/1975  781-82-8921        Nevada
# 646      21   Michelle Brewer   6/10/1988  038-84-6836      Oklahoma
# 647     362      Hannah Nolan   9/15/1978  570-46-1332      Oklahoma
# 648     368     Erica Johnson   5/27/1978  620-05-9413     Louisiana
# 649     323     Jeremy Obrien   1/13/1982  153-17-7592        Oregon
#
# [650 rows x 5 columns]

# %%
PyBoss2_df = PyBoss_df
PyBoss2_df.dropna(inplace = True)
PyBoss2_df[['First Name', 'Last Name']] = PyBoss2_df.Name.str.split(" ", expand=True)
PyBoss2_df.drop(columns = ['Name'], inplace = True)
PyBoss2_df
# Out:
#      Emp ID         DOB          SSN         State First Name  Last Name
# 0       232   2/24/1991  289-31-9165  North Dakota       John    Mathews
# 1       533  11/19/1978  220-05-7469         Maine     Nathan      Moore
# 2       256    1/8/1990  564-27-6961         Idaho     Amanda    Douglas
# 3       189   8/11/1976  742-79-1797       Vermont    Heather    Andrews
# 4       284   7/22/1976  656-01-7473      Colorado     Daniel  Hernandez
# ..      ...         ...          ...           ...        ...        ...
# 645     235    2/1/1975  781-82-8921        Nevada    Cameron   Mcintosh
# 646      21   6/10/1988  038-84-6836      Oklahoma   Michelle     Brewer
# 647     362   9/15/1978  570-46-1332      Oklahoma     Hannah      Nolan
# 648     368   5/27/1978  620-05-9413     Louisiana      Erica    Johnson
# 649     323   1/13/1982  153-17-7592        Oregon     Jeremy     Obrien
#
# [650 rows x 6 columns]

# %%
#PyBoss2_df['DOB'] = PyBoss2_df.DOB.apply(
    #lambda x: pd.to_datetime(x).strftime('%m/%d/%Y'))
PyBoss2_df['DOB'] = pd.to_datetime(PyBoss2_df['DOB'], dayfirst = False, yearfirst = False)
PyBoss2_df
# Out:
#      Emp ID        DOB          SSN         State First Name  Last Name
# 0       232 1991-02-24  289-31-9165  North Dakota       John    Mathews
# 1       533 1978-11-19  220-05-7469         Maine     Nathan      Moore
# 2       256 1990-01-08  564-27-6961         Idaho     Amanda    Douglas
# 3       189 1976-08-11  742-79-1797       Vermont    Heather    Andrews
# 4       284 1976-07-22  656-01-7473      Colorado     Daniel  Hernandez
# ..      ...        ...          ...           ...        ...        ...
# 645     235 1975-02-01  781-82-8921        Nevada    Cameron   Mcintosh
# 646      21 1988-06-10  038-84-6836      Oklahoma   Michelle     Brewer
# 647     362 1978-09-15  570-46-1332      Oklahoma     Hannah      Nolan
# 648     368 1978-05-27  620-05-9413     Louisiana      Erica    Johnson
# 649     323 1982-01-13  153-17-7592        Oregon     Jeremy     Obrien
#
# [650 rows x 6 columns]

# %%
PyBoss3_df = PyBoss2_df
PyBoss3_df.SSN = PyBoss2_df.SSN.apply(lambda x: re.sub(r'\d', '*', x, count=5))
PyBoss3_df
# Out:
#      Emp ID        DOB          SSN         State First Name  Last Name
# 0       232 1991-02-24  ***-**-9165  North Dakota       John    Mathews
# 1       533 1978-11-19  ***-**-7469         Maine     Nathan      Moore
# 2       256 1990-01-08  ***-**-6961         Idaho     Amanda    Douglas
# 3       189 1976-08-11  ***-**-1797       Vermont    Heather    Andrews
# 4       284 1976-07-22  ***-**-7473      Colorado     Daniel  Hernandez
# ..      ...        ...          ...           ...        ...        ...
# 645     235 1975-02-01  ***-**-8921        Nevada    Cameron   Mcintosh
# 646      21 1988-06-10  ***-**-6836      Oklahoma   Michelle     Brewer
# 647     362 1978-09-15  ***-**-1332      Oklahoma     Hannah      Nolan
# 648     368 1978-05-27  ***-**-9413     Louisiana      Erica    Johnson
# 649     323 1982-01-13  ***-**-7592        Oregon     Jeremy     Obrien
#
# [650 rows x 6 columns]

# %%
state_url = 'https://gist.github.com/afhaque/29f0f4f37463c447770517a6c17d08f5#file-us_state_abbrev-py'
r = requests.get(state_url)
state_df = pd.DataFrame(r.
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-11-c279be4dd1b9> in <module>
#       1 state_url = 'https://gist.github.com/afhaque/29f0f4f37463c447770517a6c17d08f5#file-us_state_abbrev-py'
#       2 r = requests.get(state_url)
# ----> 3 state_df = pd.DataFrame(r.json())
#
# ~\anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 7 column 1 (char 6)

# %%
PyBoss4_df['State'] = PyBoss3_df['State'].map(state)
PyBoss4_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-25e872364a52> in <module>
# ----> 1 PyBoss4_df['State'] = PyBoss3_df['State'].map(state_url)
#       2 PyBoss4_df
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3628         dtype: object
#    3629         """
# -> 3630         new_values = super()._map_values(arg, na_action=na_action)
#    3631         return self._constructor(new_values, index=self.index).__finalize__(self)
#    3632
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#    1152
#    1153         # mapper is a function
# -> 1154         new_values = map_f(values, mapper)
#    1155
#    1156         return new_values
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# TypeError: 'str' object is not callable
